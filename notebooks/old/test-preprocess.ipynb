# %%
from hydrosense.database.bigquery import load_piezo_bq
from hydrosense.preprocess.cleaning import clean_piezo

# load from big query
df_raw = load_piezo_bq("BSS001QHYH")
df_raw.head()
# Out:
# /home/yanns/.pyenv/versions/3.10.6/envs/Projet_Hydrosense/lib/python3.10/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# BSS001QHYH : 14532 lignes chargées
#              niveau_nappe_eau
# date_mesure
# 1985-06-24              12.54
# 1985-06-25              12.54
# 1985-06-26              12.54
# 1985-06-27              12.54
# 1985-06-28              12.51

# %%
df_raw.shape
# Out:
# (14532, 1)

# %%
# test cleaning
df_clean = clean_piezo(df_raw)
# Out:
# Trou de 224 jours détecté !
# 2751 lignes antérieures à 1994-01-18 supprimées !
# DataFrame final : 1994-01-18 → 2026-05-30 | 11821 jours

# %%
# check
print(df_clean.shape)
print(df_clean.isna().sum())  # doit être 0
df_clean.plot(figsize=(12, 4))
# Out:
# (11821, 1)
# niveau_nappe_eau    0
# dtype: int64
# <Axes: xlabel='date_mesure'>
