# %% [markdown]
# # test bigquery

# %%
# !pip install python-dotenv google-cloud-bigquery db-dtypes

# %%
# Cellule 1 — imports & auth
# from dotenv import load_dotenv
# load_dotenv()

# from google.cloud import bigquery
# import pandas as pd

client = bigquery.Client(project="hydro-sense-498112")
print("Connecté ✅")
# Out:
# Connecté ✅
